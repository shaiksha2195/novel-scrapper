# %%
from bs4 import BeautifulSoup as bs

# %%
import requests
page = requests.get("http://www.boxnovel.com");

# %%
soup = bs(page.content, "html.parser")

# %%
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html lang="en-US" prefix="og: http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://boxnovel.com/xmlrpc.php" rel="pingback"/>
# <title>HOME</title>
# <!-- This site is optimized with the Yoast SEO plugin v11.1 - https://yoast.com/wordpress/plugins/seo/ -->
# <meta content="Read free English translated Light Novel online, Chinese Novel, Korean Novel" name="description">
# <link href="https://boxnovel.com/" rel="canonical">
# <meta content="en_US" property="og:locale">
# <meta content="website" property="og:type"/>
# <meta content="HOME" property="og:title"/>
# <meta content="Read free English translated Light Novel online, Chinese Novel, Korean Novel" property="og:description"/>
# <meta content="https://boxnovel.com/" property="og:url"/>
# ...

# %%
for x in soup.find_all('p', class_='wp-manga-chapter');
